# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('linear regression/data/Salary_Data.csv')

# %%
#series is col row is field and record is col k against row ko kahtay han

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
#read random
df.sample()
# Out:
#    YearsExperience   Salary
# 2              1.5  37731.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
#only shopw the summary of descriptive col 
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#label based indexing 
#i loc

# %%
df.iloc[25]
# Out:
# YearsExperience         9.0
# Salary             105582.0
# Name: 25, dtype: float64

# %%
plt.title('Salary Distribution ')
plt.xlabel('amount of salary')
plt.ylabel('Density')
plt.hist(df['Salary'],bins=5,edgecolor='black',color='green')
plt.show()

# %%
#univariate analysis(one col)
plt.figure(figsize=(8,4))
plt.title('Salary Distribution ')
plt.xlabel('amount of salary')
plt.ylabel('Density')
sns.histplot(df['Salary'],kde='true')
plt.grid(True)
plt.savefig('salary_distribution_histogram.png')
plt.show()

# %%
#bivariate Analysis 
plt.scatter(df['YearsExperience'],df['Salary'])
plt.title('salary vs exp')
plt.xlabel('year of exp')
plt.ylabel('salary')

plt.show()

# %%
sns.scatterplot(data=df,x='YearsExperience',y='Salary')
plt.title('salary vs exp')
plt.xlabel('year of exp')
plt.ylabel('salary')

plt.show()

# %%
#correlation aik variable ka dusray variable par dependency kya hai 
correlation=df['YearsExperience'].corr(df['Salary'])
print('correlation is ',correlation)
# Out:
# correlation is  0.9782416184887599

# %%
#model is nothing it is mathematical expresssion 
#super vised machine learning targeted col and class label 
#data ki nature continuous nature variation in nature to haito wo regression hogi 
#CLASSIFICATION DI HUI HAI job lagi nahi lagi ? yes or no or discreate type ka data hai to classification hogi hogi |limited values 
#unsupervised (no labeld data )

# %%
#classification agar 2 hi classes han to binary clasiification hai two output col
#more than two output multi class hai multi level alag hai

# %%
#output col konsa hai ya class col konsa hai

# %%
#mssing value

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#col unnessary remv karny k lya 
#x=df.drop(columns=[list of col name] )

# %%
X=df.drop(columns=['Salary'])
y=df['Salary']

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_train,y_test=train_test_split(X,y,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_train,y_test=train_test_split(X,y)
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
from sklearn.linear_model import LinearRegression
